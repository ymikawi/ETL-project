# %%
# SQL Alchemy
from sqlalchemy import create_engine

# PyMySQL 
import pymysql
pymysql.install_as_MySQLdb()

# Set path 
import sys
sys.path.append('../')

# %%
# Config variables
from config import remote_db_endpoint, remote_db_port
from config import remote_gwsis_dbname, remote_gwsis_dbuser, remote_gwsis_dbpwd
from config import local_gwsis_dbname, local_gwsis_dbuser, local_gwsis_dbpwd 

# Import Pandas
import pandas as pd

# %%
# local Connection Backup 
lengine = create_engine(f"mysql://{local_gwsis_dbuser}:{local_gwsis_dbpwd}@localhost:3306/{local_gwsis_dbname}")

# AWS Database Connection
engine = create_engine(f"mysql://{remote_gwsis_dbuser}:{remote_gwsis_dbpwd}@{remote_db_endpoint}:{remote_db_port}/{remote_gwsis_dbname}")

# %%
# Create a local database engine connection
lconn = lengine.connect()

# Create a remote database engine connection
conn = engine.connect()

# %%
home_listing = pd.read_csv('Alexandria Home Listings.csv')
home_listing.head()

home_listing.columns=['Index', 'House Url', 'Facts and Features', 'Address']
home_listing
# Out:
#     Index                                          House Url  \
# 0       0  https://www.zillow.com/alexandria-va/houses//h...
# 1       1  https://www.zillow.com/alexandria-va/houses//h...
# 2       2  https://www.zillow.com/alexandria-va/houses//h...
# 3       3  https://www.zillow.com/alexandria-va/houses//h...
# 4       4  https://www.zillow.com/alexandria-va/houses//h...
# 5       5  https://www.zillow.com/alexandria-va/houses//h...
# 6       6  https://www.zillow.com/alexandria-va/houses//h...
# 7       7  https://www.zillow.com/alexandria-va/houses//h...
# 8       8  https://www.zillow.com/alexandria-va/houses//h...
# 9       9  https://www.zillow.com/alexandria-va/houses//h...
# 10     10  https://www.zillow.com/alexandria-va/houses//h...
# 11     11  https://www.zillow.com/alexandria-va/houses//h...
# 12     12  https://www.zillow.com/alexandria-va/houses//h...
# 13     13  https://www.zillow.com/alexandria-va/houses//h...
# ...

# %%
home_listing_data.to_sql(name='home_listing', if_exists='append', con=conn, chunksize=500, index=False)

# %%
public_schools_data = pd.read_csv('Alexandria Public Schools.csv')
public_schools_data.head()
# Out:
#    Unnamed: 0 State School ID  NCES District ID State District ID Low Grade*  \
# 0           0  VA-029-0292244           5101260            VA-029          †
# 1           1  VA-029-0292212           5101260            VA-029          †
# 2           2  VA-029-0292246           5101260            VA-029          †
# 3           3  VA-029-0290560           5101260            VA-029         PK
# 4           4  VA-029-0290940           5101260            VA-029         PK
#
#   High Grade*                         School Name              District  \
# 0           †  Achievement Integrity And Maturity  FAIRFAX CO PBLC SCHS
# 1           †                       ALC at Bryant  FAIRFAX CO PBLC SCHS
# 2           †                     ALC at Montrose  FAIRFAX CO PBLC SCHS
# 3           6               Belle View Elementary  FAIRFAX CO PBLC SCHS
# 4           5            Bren Mar Park Elementary  FAIRFAX CO PBLC SCHS
#
# ...

# %%
public_schools_data.to_sql(name='public_schools_data', if_exists='append', con=conn, chunksize=500, index=False)

# %%
private_schools_data = pd.read_csv('Alexandria Private Schools.csv')
private_schools_data.head()
# Out:
#    Unnamed: 0 School ID                             Private School Name  \
# 0           0  A9304116                   ALEXANDRIA COUNTRY DAY SCHOOL
# 1           1   1432368                       BISHOP IRETON HIGH SCHOOL
# 2           2   1636066  BLESSED SACRAMENT SCHOOL & EARLY CHILDHOOD CTR
# 3           3  A0971723                               BRENTWOOD ACADEMY
# 4           4   1433689                                  BROWNE ACADEMY
#
#    Private Low Grade  Private High Grade     Private Address        City  \
# 0                  3                  13     2400 RUSSELL RD  ALEXANDRIA
# 1                 14                  17    201 CAMBRIDGE RD  ALEXANDRIA
# 2                  2                  13  1417 W BRADDOCK RD  ALEXANDRIA
# 3                  2                   7       3725 NALLS RD  ALEXANDRIA
# 4                  2                  13   5917 TELEGRAPH RD  ALEXANDRIA
#
#    PSS_COUNTY_NO  PSS_COUNTY_FIPS PSS_STABB      ...       PSS_ENROLL_K  \
# ...

# %%
private_schools_data.to_sql(name='private_schools_data', if_exists='append', con=conn, chunksize=500, index=False)

# %%
#Check to see if it was loaded onto AWS and populated in MySQL
private_schools=pd.read_sql ("SELECT * FROM private_schools_data", conn)
private_schools.head()
# Out:
#    Unnamed: 0 School ID                             Private School Name  \
# 0           0  A9304116                   ALEXANDRIA COUNTRY DAY SCHOOL
# 1           1   1432368                       BISHOP IRETON HIGH SCHOOL
# 2           2   1636066  BLESSED SACRAMENT SCHOOL & EARLY CHILDHOOD CTR
# 3           3  A0971723                               BRENTWOOD ACADEMY
# 4           4   1433689                                  BROWNE ACADEMY
#
#    Private Low Grade  Private High Grade     Private Address        City  \
# 0                  3                  13     2400 RUSSELL RD  ALEXANDRIA
# 1                 14                  17    201 CAMBRIDGE RD  ALEXANDRIA
# 2                  2                  13  1417 W BRADDOCK RD  ALEXANDRIA
# 3                  2                   7       3725 NALLS RD  ALEXANDRIA
# 4                  2                  13   5917 TELEGRAPH RD  ALEXANDRIA
#
#    PSS_COUNTY_NO  PSS_COUNTY_FIPS PSS_STABB      ...       PSS_ENROLL_K  \
# ...

# %%
public_schools=pd.read_sql ("SELECT * FROM public_schools_data", conn)
public_schools.head()
# Out:
#    Unnamed: 0 State School ID  NCES District ID State District ID Low Grade*  \
# 0           0  VA-029-0292244           5101260            VA-029          †
# 1           1  VA-029-0292212           5101260            VA-029          †
# 2           2  VA-029-0292246           5101260            VA-029          †
# 3           3  VA-029-0290560           5101260            VA-029         PK
# 4           4  VA-029-0290940           5101260            VA-029         PK
#
#   High Grade*                         School Name              District  \
# 0           †  Achievement Integrity And Maturity  FAIRFAX CO PBLC SCHS
# 1           †                       ALC at Bryant  FAIRFAX CO PBLC SCHS
# 2           †                     ALC at Montrose  FAIRFAX CO PBLC SCHS
# 3           6               Belle View Elementary  FAIRFAX CO PBLC SCHS
# 4           5            Bren Mar Park Elementary  FAIRFAX CO PBLC SCHS
#
# ...

# %%
##
